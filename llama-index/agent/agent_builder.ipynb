# %% [markdown]
# # GPT Builder Demo
#
# <a href="https://colab.research.google.com/github/run-llama/llama_index/blob/main/docs/docs/examples/agent/agent_builder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Inspired by GPTs interface, presented at OpenAI Dev Day 2023. Construct an agent with natural language.
#
# Here you can build your own agent...with another agent!

# %%
# %pip install llama-index-agent-openai
# %pip install llama-index-embeddings-openai
# %pip install llama-index-llms-openai
# Out:
# Requirement already satisfied: llama-index-agent-openai in /home/vscode/.local/lib/python3.11/site-packages (0.4.6)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.18 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-agent-openai) (0.12.19)
# Requirement already satisfied: llama-index-llms-openai<0.4.0,>=0.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-agent-openai) (0.3.20)
# Requirement already satisfied: openai>=1.14.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-agent-openai) (1.63.2)
# Collecting PyYAML>=6.0.1 (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai)
#   Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /home/vscode/.local/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (3.11.12)
# Requirement already satisfied: dataclasses-json in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (2025.2.0)
# Collecting httpx (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (3.9.1)
# Requirement already satisfied: numpy in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (2.2.3)
# Requirement already satisfied: pillow>=9.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (2.10.6)
# Collecting requests>=2.31.0 (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (0.9.0)
# Requirement already satisfied: wrapt in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (1.17.2)
# Collecting anyio<5,>=3.5.0 (from openai>=1.14.0->llama-index-agent-openai)
#   Downloading anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/vscode/.local/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from openai>=1.14.0->llama-index-agent-openai) (0.8.2)
# Collecting sniffio (from openai>=1.14.0->llama-index-agent-openai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (1.3.2)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai)
#   Downloading attrs-25.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (1.18.3)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi (from httpx->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai)
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: click in /home/vscode/.local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (8.1.8)
# Requirement already satisfied: joblib in /home/vscode/.local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/vscode/.local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (2.27.2)
# Collecting charset-normalizer<4,>=2 (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai)
#   Downloading charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/vscode/.local/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /home/vscode/.local/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.18->llama-index-agent-openai) (24.2)
# Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
# Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 18.9 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (143 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: urllib3, sniffio, PyYAML, idna, h11, charset-normalizer, certifi, attrs, requests, httpcore, anyio, httpx
# Successfully installed PyYAML-6.0.2 anyio-4.8.0 attrs-25.1.0 certifi-2025.1.31 charset-normalizer-3.4.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 idna-3.10 requests-2.32.3 sniffio-1.3.1 urllib3-2.3.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-embeddings-openai in /home/vscode/.local/lib/python3.11/site-packages (0.3.1)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-embeddings-openai) (0.12.19)
# Requirement already satisfied: openai>=1.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-embeddings-openai) (1.63.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/python/current/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /home/vscode/.local/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.11.12)
# Requirement already satisfied: dataclasses-json in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2025.2.0)
# Requirement already satisfied: httpx in /usr/local/python/current/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.9.1)
# Requirement already satisfied: numpy in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.2.3)
# Requirement already satisfied: pillow>=9.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/python/current/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: wrapt in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.17.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/python/current/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/vscode/.local/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/python/current/lib/python3.11/site-packages (from openai>=1.1.0->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/python/current/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/python/current/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/python/current/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/python/current/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/python/current/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.14.0)
# Requirement already satisfied: click in /home/vscode/.local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (8.1.8)
# Requirement already satisfied: joblib in /home/vscode/.local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/vscode/.local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/python/current/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/current/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/vscode/.local/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /home/vscode/.local/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-openai) (24.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: llama-index-llms-openai in /home/vscode/.local/lib/python3.11/site-packages (0.3.20)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.17 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-llms-openai) (0.12.19)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-llms-openai) (1.63.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/python/current/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /home/vscode/.local/lib/python3.11/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (3.11.12)
# Requirement already satisfied: dataclasses-json in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2025.2.0)
# Requirement already satisfied: httpx in /usr/local/python/current/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (3.9.1)
# Requirement already satisfied: numpy in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.2.3)
# Requirement already satisfied: pillow>=9.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.10.6)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/python/current/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.9.0)
# Requirement already satisfied: wrapt in /home/vscode/.local/lib/python3.11/site-packages (from llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.17.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/python/current/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/vscode/.local/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/python/current/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/python/current/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/python/current/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->llama-index-llms-openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/python/current/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/python/current/lib/python3.11/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/python/current/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.14.0)
# Requirement already satisfied: click in /home/vscode/.local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (8.1.8)
# Requirement already satisfied: joblib in /home/vscode/.local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/vscode/.local/lib/python3.11/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/python/current/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/current/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/vscode/.local/lib/python3.11/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/vscode/.local/lib/python3.11/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /home/vscode/.local/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.17->llama-index-llms-openai) (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install kitchenai-whisk
# Out:
# Collecting kitchenai-whisk
#   Downloading kitchenai_whisk-0.2.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: anyio>=3.7.1 in /usr/local/python/current/lib/python3.11/site-packages (from kitchenai-whisk) (4.8.0)
# Collecting cookiecutter>=2.5.0 (from kitchenai-whisk)
#   Downloading cookiecutter-2.6.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting fastapi>=0.100.0 (from kitchenai-whisk)
#   Downloading fastapi-0.115.8-py3-none-any.whl.metadata (27 kB)
# Collecting faststream>=0.4.0 (from faststream[nats]>=0.4.0->kitchenai-whisk)
#   Downloading faststream-0.5.34-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: httpx>=0.26.0 in /usr/local/python/current/lib/python3.11/site-packages (from kitchenai-whisk) (0.28.1)
# Requirement already satisfied: pydantic>=2.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from kitchenai-whisk) (2.10.6)
# Collecting python-multipart (from kitchenai-whisk)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/python/current/lib/python3.11/site-packages (from kitchenai-whisk) (6.0.2)
# Collecting rich>=13.7.0 (from kitchenai-whisk)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting typer>=0.9.0 (from kitchenai-whisk)
#   Downloading typer-0.15.1-py3-none-any.whl.metadata (15 kB)
# Collecting uvicorn>=0.27.0 (from kitchenai-whisk)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting watchfiles (from kitchenai-whisk)
#   Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/python/current/lib/python3.11/site-packages (from anyio>=3.7.1->kitchenai-whisk) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/python/current/lib/python3.11/site-packages (from anyio>=3.7.1->kitchenai-whisk) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /home/vscode/.local/lib/python3.11/site-packages (from anyio>=3.7.1->kitchenai-whisk) (4.12.2)
# Collecting binaryornot>=0.4.4 (from cookiecutter>=2.5.0->kitchenai-whisk)
#   Downloading binaryornot-0.4.4-py2.py3-none-any.whl.metadata (6.0 kB)
# Collecting Jinja2<4.0.0,>=2.7 (from cookiecutter>=2.5.0->kitchenai-whisk)
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: click<9.0.0,>=7.0 in /home/vscode/.local/lib/python3.11/site-packages (from cookiecutter>=2.5.0->kitchenai-whisk) (8.1.8)
# Collecting python-slugify>=4.0.0 (from cookiecutter>=2.5.0->kitchenai-whisk)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/python/current/lib/python3.11/site-packages (from cookiecutter>=2.5.0->kitchenai-whisk) (2.32.3)
# Collecting arrow (from cookiecutter>=2.5.0->kitchenai-whisk)
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi>=0.100.0->kitchenai-whisk)
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting fast-depends<3.0.0,>=2.4.0b0 (from faststream>=0.4.0->faststream[nats]>=0.4.0->kitchenai-whisk)
#   Downloading fast_depends-2.4.12-py3-none-any.whl.metadata (7.6 kB)
# Collecting nats-py<=3.0.0,>=2.7.0 (from faststream[nats]>=0.4.0->kitchenai-whisk)
#   Downloading nats_py-2.9.0.tar.gz (110 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: certifi in /usr/local/python/current/lib/python3.11/site-packages (from httpx>=0.26.0->kitchenai-whisk) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/python/current/lib/python3.11/site-packages (from httpx>=0.26.0->kitchenai-whisk) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/python/current/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.26.0->kitchenai-whisk) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic>=2.0.0->kitchenai-whisk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic>=2.0.0->kitchenai-whisk) (2.27.2)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.7.0->kitchenai-whisk)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/vscode/.local/lib/python3.11/site-packages (from rich>=13.7.0->kitchenai-whisk) (2.19.1)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->kitchenai-whisk)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting chardet>=3.0.2 (from binaryornot>=0.4.4->cookiecutter>=2.5.0->kitchenai-whisk)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting MarkupSafe>=2.0 (from Jinja2<4.0.0,>=2.7->cookiecutter>=2.5.0->kitchenai-whisk)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.7.0->kitchenai-whisk)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting text-unidecode>=1.3 (from python-slugify>=4.0.0->cookiecutter>=2.5.0->kitchenai-whisk)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/python/current/lib/python3.11/site-packages (from requests>=2.23.0->cookiecutter>=2.5.0->kitchenai-whisk) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/current/lib/python3.11/site-packages (from requests>=2.23.0->cookiecutter>=2.5.0->kitchenai-whisk) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /home/vscode/.local/lib/python3.11/site-packages (from arrow->cookiecutter>=2.5.0->kitchenai-whisk) (2.9.0.post0)
# Collecting types-python-dateutil>=2.8.10 (from arrow->cookiecutter>=2.5.0->kitchenai-whisk)
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.11/site-packages (from python-dateutil>=2.7.0->arrow->cookiecutter>=2.5.0->kitchenai-whisk) (1.17.0)
# Downloading kitchenai_whisk-0.2.1-py3-none-any.whl (42 kB)
# Downloading cookiecutter-2.6.0-py3-none-any.whl (39 kB)
# Downloading fastapi-0.115.8-py3-none-any.whl (94 kB)
# Downloading faststream-0.5.34-py3-none-any.whl (386 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading typer-0.15.1-py3-none-any.whl (44 kB)
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
# Downloading binaryornot-0.4.4-py2.py3-none-any.whl (9.0 kB)
# Downloading fast_depends-2.4.12-py3-none-any.whl (17 kB)
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Building wheels for collected packages: nats-py
#   Building wheel for nats-py (pyproject.toml) ... done
#   Created wheel for nats-py: filename=nats_py-2.9.0-py3-none-any.whl size=82408 sha256=17b6e2ec146bc5628344850357346b23e5bdeb901d4d06c29a84159418b7b1e0
#   Stored in directory: /home/vscode/.cache/pip/wheels/fa/b3/aa/51dcde9efd28f508e2891e10e87699a4ca9fa2bc0270d5a334
# Successfully built nats-py
# Installing collected packages: text-unidecode, uvicorn, types-python-dateutil, shellingham, python-slugify, python-multipart, nats-py, mdurl, MarkupSafe, chardet, watchfiles, starlette, markdown-it-py, Jinja2, binaryornot, arrow, rich, fastapi, fast-depends, typer, faststream, cookiecutter, kitchenai-whisk
# Successfully installed Jinja2-3.1.5 MarkupSafe-3.0.2 arrow-1.3.0 binaryornot-0.4.4 chardet-5.2.0 cookiecutter-2.6.0 fast-depends-2.4.12 fastapi-0.115.8 faststream-0.5.34 kitchenai-whisk-0.2.1 markdown-it-py-3.0.0 mdurl-0.1.2 nats-py-2.9.0 python-multipart-0.0.20 python-slugify-8.0.4 rich-13.9.4 shellingham-1.5.4 starlette-0.45.3 text-unidecode-1.3 typer-0.15.1 types-python-dateutil-2.9.0.20241206 uvicorn-0.34.0 watchfiles-1.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

api_key = input("Please enter your OpenAI API key: ")
os.environ["OPENAI_API_KEY"] = api_key

# %%
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.llms.openai import OpenAI
from llama_index.core import Settings

llm = OpenAI(model="gpt-4")
Settings.llm = llm
Settings.embed_model = OpenAIEmbedding(model="text-embedding-3-small")

# %% [markdown]
# ## Define Candidate Tools
#
# We also define a tool retriever to retrieve candidate tools.
#
# In this setting we define tools as different Wikipedia pages.

# %%
from llama_index.core import SimpleDirectoryReader

# %%
wiki_titles = ["Toronto", "Seattle", "Chicago", "Boston", "Houston"]

# %%
from pathlib import Path

import requests

for title in wiki_titles:
    response = requests.get(
        "https://en.wikipedia.org/w/api.php",
        params={
            "action": "query",
            "format": "json",
            "titles": title,
            "prop": "extracts",
            # 'exintro': True,
            "explaintext": True,
        },
    ).json()
    page = next(iter(response["query"]["pages"].values()))
    wiki_text = page["extract"]

    data_path = Path("data")
    if not data_path.exists():
        Path.mkdir(data_path)

    with open(data_path / f"{title}.txt", "w") as fp:
        fp.write(wiki_text)

# %%
# Load all wiki documents
city_docs = {}
for wiki_title in wiki_titles:
    city_docs[wiki_title] = SimpleDirectoryReader(
        input_files=[f"data/{wiki_title}.txt"]
    ).load_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/llama_index/core/readers/file/base.py:65, in _try_loading_included_file_formats()
#      64 try:
# ---> 65     from llama_index.readers.file import (
#      66         DocxReader,
#      67         EpubReader,
#      68         HWPReader,
#      69         ImageReader,
#      70         IPYNBReader,
#      71         MboxReader,
#      72         PandasCSVReader,
#      73         PandasExcelReader,
#      74         PDFReader,
#      75         PptxReader,
#      76         VideoAudioReader,
#      77     )  # pants: no-infer-dep
#      78 except ImportError:
#
# ModuleNotFoundError: No module named 'llama_index.readers'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 6
#       2 city_docs = {}
#       3 for wiki_title in wiki_titles:
#       4     city_docs[wiki_title] = SimpleDirectoryReader(
#       5         input_files=[f"data/{wiki_title}.txt"]
# ----> 6     ).load_data()
#
# File ~/.local/lib/python3.11/site-packages/llama_index/core/readers/file/base.py:722, in SimpleDirectoryReader.load_data(self, show_progress, num_workers, fs)
#     717         files_to_process = tqdm(
#     718             self.input_files, desc="Loading files", unit="file"
#     719         )
#     720     for input_file in files_to_process:
#     721         documents.extend(
# --> 722             SimpleDirectoryReader.load_file(
#     723                 input_file=input_file,
#     724                 file_metadata=self.file_metadata,
#     725                 file_extractor=self.file_extractor,
#     726                 filename_as_id=self.filename_as_id,
#     727                 encoding=self.encoding,
#     728                 errors=self.errors,
#     729                 raise_on_error=self.raise_on_error,
#     730                 fs=fs,
#     731             )
#     732         )
#     734 return self._exclude_metadata(documents)
#
# File ~/.local/lib/python3.11/site-packages/llama_index/core/readers/file/base.py:540, in SimpleDirectoryReader.load_file(input_file, file_metadata, file_extractor, filename_as_id, encoding, errors, raise_on_error, fs)
#     507 """
#     508 Static method for loading file.
#     509
#    (...)
#     537     List[Document]: loaded documents
#     538 """
#     539 # TODO: make this less redundant
# --> 540 default_file_reader_cls = SimpleDirectoryReader.supported_suffix_fn()
#     541 default_file_reader_suffix = list(default_file_reader_cls.keys())
#     542 metadata: dict | None = None
#
# File ~/.local/lib/python3.11/site-packages/llama_index/core/readers/file/base.py:79, in _try_loading_included_file_formats()
#      65     from llama_index.readers.file import (
#      66         DocxReader,
#      67         EpubReader,
#    (...)
#      76         VideoAudioReader,
#      77     )  # pants: no-infer-dep
#      78 except ImportError:
# ---> 79     raise ImportError("`llama-index-readers-file` package not found")
#      81 default_file_reader_cls: dict[str, Type[BaseReader]] = {
#      82     ".hwp": HWPReader,
#      83     ".pdf": PDFReader,
#    (...)
#     100     ".xlsx": PandasExcelReader,
#     101 }
#     102 return default_file_reader_cls
#
# ImportError: `llama-index-readers-file` package not found

# %% [markdown]
# ### Build Query Tool for Each Document

# %%
from llama_index.core import VectorStoreIndex
from llama_index.agent.openai import OpenAIAgent
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core import VectorStoreIndex

# Build tool dictionary
tool_dict = {}

for wiki_title in wiki_titles:
    # build vector index
    vector_index = VectorStoreIndex.from_documents(
        city_docs[wiki_title],
    )
    # define query engines
    vector_query_engine = vector_index.as_query_engine(llm=llm)

    # define tools
    vector_tool = QueryEngineTool(
        query_engine=vector_query_engine,
        metadata=ToolMetadata(
            name=wiki_title,
            description=("Useful for questions related to" f" {wiki_title}"),
        ),
    )
    tool_dict[wiki_title] = vector_tool

# %% [markdown]
# ### Define Tool Retriever

# %%
# define an "object" index and retriever over these tools
from llama_index.core import VectorStoreIndex
from llama_index.core.objects import ObjectIndex

tool_index = ObjectIndex.from_objects(
    list(tool_dict.values()),
    index_cls=VectorStoreIndex,
)
tool_retriever = tool_index.as_retriever(similarity_top_k=1)

# %% [markdown]
# ### Load Data
#
# Here we load wikipedia pages from different cities.

# %% [markdown]
# ## Define Meta-Tools for GPT Builder

# %%
from llama_index.core.llms import ChatMessage
from llama_index.core import ChatPromptTemplate
from typing import List

GEN_SYS_PROMPT_STR = """\
Task information is given below. 

Given the task, please generate a system prompt for an OpenAI-powered bot to solve this task: 
{task} \
"""

gen_sys_prompt_messages = [
    ChatMessage(
        role="system",
        content="You are helping to build a system prompt for another bot.",
    ),
    ChatMessage(role="user", content=GEN_SYS_PROMPT_STR),
]

GEN_SYS_PROMPT_TMPL = ChatPromptTemplate(gen_sys_prompt_messages)


agent_cache = {}


def create_system_prompt(task: str):
    """Create system prompt for another agent given an input task."""
    llm = OpenAI(llm="gpt-4")
    fmt_messages = GEN_SYS_PROMPT_TMPL.format_messages(task=task)
    response = llm.chat(fmt_messages)
    return response.message.content


def get_tools(task: str):
    """Get the set of relevant tools to use given an input task."""
    subset_tools = tool_retriever.retrieve(task)
    return [t.metadata.name for t in subset_tools]


def create_agent(system_prompt: str, tool_names: List[str]):
    """Create an agent given a system prompt and an input set of tools."""
    llm = OpenAI(model="gpt-4")
    try:
        # get the list of tools
        input_tools = [tool_dict[tn] for tn in tool_names]

        agent = OpenAIAgent.from_tools(input_tools, llm=llm, verbose=True)
        agent_cache["agent"] = agent
        return_msg = "Agent created successfully."
    except Exception as e:
        return_msg = f"An error occurred when building an agent. Here is the error: {repr(e)}"
    return return_msg

# %%
from llama_index.core.tools import FunctionTool

system_prompt_tool = FunctionTool.from_defaults(fn=create_system_prompt)
get_tools_tool = FunctionTool.from_defaults(fn=get_tools)
create_agent_tool = FunctionTool.from_defaults(fn=create_agent)

# %%
GPT_BUILDER_SYS_STR = """\
You are helping to construct an agent given a user-specified task. You should generally use the tools in this order to build the agent.

1) Create system prompt tool: to create the system prompt for the agent.
2) Get tools tool: to fetch the candidate set of tools to use.
3) Create agent tool: to create the final agent.
"""

prefix_msgs = [ChatMessage(role="system", content=GPT_BUILDER_SYS_STR)]


builder_agent = OpenAIAgent.from_tools(
    tools=[system_prompt_tool, get_tools_tool, create_agent_tool],
    prefix_messages=prefix_msgs,
    verbose=True,
)

# %%
builder_agent.query("Build an agent that can tell me about Toronto.")
# Out:
# Added user message to memory: Build an agent that can tell me about Toronto.
# === Calling Function ===
# Calling function: create_system_prompt with args: {
#   "task": "tell me about Toronto"
# }
# Got output: "Generate a brief summary about Toronto, including its history, culture, landmarks, and notable features."
# ========================
#
# === Calling Function ===
# Calling function: get_tools with args: {
#   "task": "tell me about Toronto"
# }
# Got output: ['Toronto']
# ========================
#
# === Calling Function ===
# Calling function: create_agent with args: {
#   "system_prompt": "Generate a brief summary about Toronto, including its history, culture, landmarks, and notable features.",
#   "tool_names": ["Toronto"]
# }
# Got output: Agent created successfully.
# ========================
# Response(response='The agent has been successfully created. It can now provide information about Toronto, including its history, culture, landmarks, and notable features.', source_nodes=[], metadata=None)

# %%
city_agent = agent_cache["agent"]

# %%
response = city_agent.query("Tell me about the parks in Toronto")
print(str(response))
# Out:
# Added user message to memory: Tell me about the parks in Toronto
# Toronto is known for its beautiful and diverse parks. Here are a few of the most popular ones:
#
# 1. **High Park**: This is Toronto's largest public park featuring many hiking trails, sports facilities, a beautiful lakefront, convenient parking, easy public transit access, a dog park, a zoo, and playgrounds for children. It's also known for its spring cherry blossoms.
#
# 2. **Toronto Islands**: A group of small islands located just off the shore of the city's downtown district, offering stunning views of the city skyline. The islands provide a great escape from the city with their car-free environment, picnic spots, swimming beaches, and Centreville Amusement Park.
#
# 3. **Trinity Bellwoods Park**: A popular park in the downtown area, it's a great place for picnics, sports, dog-walking, or just relaxing. It also has a community recreation centre with a pool and gym.
#
# 4. **Rouge National Urban Park**: Located in the city's east end, this is Canada's first national urban park. It offers hiking, swimming, camping, and a chance to learn about the area's cultural and agricultural heritage.
#
# 5. **Riverdale Farm**: This 7.5-acre farm in the heart of Toronto provides an opportunity to experience farm life and interact with a variety of farm animals.
#
# 6. **Evergreen Brick Works**: A former industrial site that has been transformed into an eco-friendly community center with a park, farmers market, and cultural events.
#
# 7. **Scarborough Bluffs Park**: Offers a unique natural environment with stunning views of Lake Ontario from atop the bluffs.
#
# 8. **Edwards Gardens**: A beautiful botanical garden located in North York, perfect for a peaceful walk surrounded by nature.
#
# 9. **Sunnybrook Park**: A large public park that offers many recreational activities including horseback riding, sports fields, and picnic areas.
#
# 10. **Cherry Beach**: Located on the waterfront, this park offers a sandy beach, picnic areas, and a dog off-leash area. It's a great spot for swimming, sunbathing, and barbecuing.
#
# These parks offer a variety of experiences, from urban amenities to natural beauty, making Toronto a great city for outdoor enthusiasts.
